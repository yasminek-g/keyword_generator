# %%
import requests
from bs4 import BeautifulSoup
import urllib.parse

import time
import json
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException

# %%
chrome_options = webdriver.ChromeOptions()
# Uncomment to run without the browser UI for faster scraping in production
chrome_options.add_argument("--headless")
service = Service('/usr/local/bin/chromedriver')  # Adjust path as needed
driver = webdriver.Chrome(service=service, options=chrome_options)

topics = [
    "Engineering", "Science", "Mathematics", "Computer Science", "Physics",
    "Mechanical Engineering", "Systems Engineering", "Electrical Engineering",
    "Differential Equations", "Probability and Statistics", "Linear Algebra", 
    "Biology", "Calculus", "Earth Science", "Materials Science and Engineering", 
    "Applied Mathematics", "Chemistry", "Algorithms and Data Structures", 
    "Thermodynamics", "Cognitive Science", "Quantum Mechanics", "Fluid Mechanics",
    "Electromagnetism", "Software Design and Engineering", "Discrete Mathematics",
    "Biological Engineering", "Chemical Engineering", "Computational Modeling and Simulation", 
    "Classical Mechanics", "Artificial Intelligence", "Mechanical Design", "Electronics",
    "Theory of Computation", "Digital Systems", "Energy", "Ocean Engineering",
    "Signal Processing", "Computer Design and Engineering", "Robotics and Control Systems", 
    "Programming Languages", "Solid Mechanics", "Civil Engineering", "Computation", 
    "Digital Media", "Systems Optimization", "Geophysics", "Algebra and Number Theory", 
    "Atomic, Molecular, Optical Physics", "Mathematical Analysis", "Physical Chemistry",
    "Data Mining", "Hydrodynamics", "Environmental Engineering", "Information Technology",
    "Systems Design", "Topology and Geometry", "Neuroscience", "Nanotechnology",
    "Geology", "Propulsion Systems", "Telecommunications", "Materials Selection", 
    "Oceanography", "Molecular Biology", "Genetics", "Transport Processes", 
    "Nuclear Engineering", "Atmospheric Science", "Nuclear Physics", "Computer Networks", 
    "Dynamics and Control", "Biochemistry", "Biomaterials", "Environmental Science", 
    "Cell Biology", "Graphics and Visualization", "Particle Physics", 
    "Computational Science and Engineering", "Theoretical Physics", 
    "Computation and Systems Biology", "Organic Chemistry", "Neurobiology",
    "Structural Engineering", "Game Design", "Computational Biology", "Game Theory", 
    "Structural Mechanics", "Anatomy and Physiology", "Biomedicine", "Planetary Science",
    "Electronic Materials", "Technology", "Electricity", "Nuclear", "Sensory-Neural Systems", 
    "Econometrics", "Human-Computer Interfaces", "Microtechnology", "Hydrology and Water Resource Systems", 
    "Cell and Tissue Engineering", "Analytical Chemistry", "Numerical Simulation",
    "Biophysics", "Geography", "Aquatic Sciences and Water Quality Control", 
    "Cryptography", "Aerodynamics", "Condensed Matter Physics", "Medical Imaging", 
    "Spectroscopy", "Climate", "Ecology", "Astrophysics", "Metallurgical Engineering", 
    "Hydrodynamics and Coastal Engineering", "Fossil Fuels", "Ocean Structures", 
    "Electric Power", "Transportation Engineering", "Functional Genomics", 
    "Biomedical Signal and Image Processing", "Biotechnology", "Synthetic Biology",
    "Architectural Engineering", "Microbiology", "Polymeric Materials", "Inorganic Chemistry", 
    "Graphic Design", "Biomechanics", "Astrodynamics", "Pharmacology and Toxicology", 
    "Polymers", "High Energy Physics", "Nuclear Materials", "Pathology and Pathophysiology", 
    "Ocean Exploration", "Mathematical Logic", "Hydrogen and Alternatives", "Biostatistics", 
    "Geobiology", "Virology", "Structural Biology", "Geotechnical Engineering", 
    "Molecular Engineering", "Bioastronautics", "Epidemiology", "Radiological Engineering", 
    "Cellular and Molecular Medicine", "Immunology", "Health and Exercise Science", 
    "Composite Materials", "Stem Cells"
]

# Initialize dictionary to store all topics and their corresponding data
all_data = {}

# Loop through each topic and scrape data
for topic in topics:
    print(f"Processing topic: {topic}")
    # Construct the URL with the current topic
    url = f"https://ocw.mit.edu/search/?r=Lecture%20Videos&t={topic.replace(' ', '%20')}&type=resourcefile&u=compact"
    driver.get(url)
    time.sleep(2)  # Initial wait for the page to load

    # Track last scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    topic_data = []
    seen_courses = set()  # To track unique courses by (resource_course_title, title)

    # Infinite scroll loop
    while True:
        # Scroll to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)  # Wait for the new content to load

        # Slightly scroll up to trigger lazy loading
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight - 500);")
        time.sleep(1)

        # Collect course elements
        course_blocks = driver.find_elements(By.CLASS_NAME, "card-contents")

        # Extract data from each course block
        for course_block in course_blocks:
            # Check for video content by finding 'cover-image-video' class
            if len(course_block.find_elements(By.CLASS_NAME, "cover-image-video")) > 0:
                try:
                    # Extract resource course title
                    resource_course_title_element = course_block.find_element(By.CLASS_NAME, "resource-course-title").find_element(By.TAG_NAME, "a")
                    resource_course_title = resource_course_title_element.text
                except NoSuchElementException:
                    resource_course_title = None

                try:
                    # Extract the lecture title
                    title_element = course_block.find_element(By.CLASS_NAME, "resource-title").find_element(By.TAG_NAME, "a")
                    title = title_element.text
                except NoSuchElementException:
                    title = None

                # Add entry to topic_data if both fields are available and unique
                if resource_course_title and title and (resource_course_title, title) not in seen_courses:
                    seen_courses.add((resource_course_title, title))
                    topic_data.append({
                        "resource_course_title": resource_course_title,
                        "title": title
                    })

        # Check if we reached the bottom of the page
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            print(f"Reached end of results for {topic}.")
            break
        last_height = new_height  # Update the last height for the next scroll

    # Store topic data in the main dictionary
    all_data[topic] = topic_data

# Close the driver
driver.quit()

# Save the collected data to a JSON file
with open("lecture_videos_data.json", "w", encoding="utf-8") as file:
    json.dump(all_data, file, ensure_ascii=False, indent=4)

print("Data saved to lecture_videos_data.json")
# Out:
# Processing topic: Engineering
# Reached end of results for Engineering.
# Processing topic: Science
# Reached end of results for Science.
# Processing topic: Mathematics
# Reached end of results for Mathematics.
# Processing topic: Computer Science
# Reached end of results for Computer Science.
# Processing topic: Physics
# Reached end of results for Physics.
# Processing topic: Mechanical Engineering
# Reached end of results for Mechanical Engineering.
# Processing topic: Systems Engineering
# Reached end of results for Systems Engineering.
# Processing topic: Electrical Engineering
# Reached end of results for Electrical Engineering.
# Processing topic: Differential Equations
# Reached end of results for Differential Equations.
# Processing topic: Probability and Statistics
# Reached end of results for Probability and Statistics.
# Processing topic: Linear Algebra
# Reached end of results for Linear Algebra.
# Processing topic: Biology
# Reached end of results for Biology.
# Processing topic: Calculus
# Reached end of results for Calculus.
# Processing topic: Earth Science
# Reached end of results for Earth Science.
# Processing topic: Materials Science and Engineering
# Reached end of results for Materials Science and Engineering.
# Processing topic: Applied Mathematics
# Reached end of results for Applied Mathematics.
# Processing topic: Chemistry
# Reached end of results for Chemistry.
# Processing topic: Algorithms and Data Structures
# Reached end of results for Algorithms and Data Structures.
# Processing topic: Thermodynamics
# Reached end of results for Thermodynamics.
# Processing topic: Cognitive Science
# Reached end of results for Cognitive Science.
# Processing topic: Quantum Mechanics
# Reached end of results for Quantum Mechanics.
# Processing topic: Fluid Mechanics
# Reached end of results for Fluid Mechanics.
# Processing topic: Electromagnetism
# Reached end of results for Electromagnetism.
# Processing topic: Software Design and Engineering
# Reached end of results for Software Design and Engineering.
# Processing topic: Discrete Mathematics
# Reached end of results for Discrete Mathematics.
# Processing topic: Biological Engineering
# Reached end of results for Biological Engineering.
# Processing topic: Chemical Engineering
# Reached end of results for Chemical Engineering.
# Processing topic: Computational Modeling and Simulation
# Reached end of results for Computational Modeling and Simulation.
# Processing topic: Classical Mechanics
# Reached end of results for Classical Mechanics.
# Processing topic: Artificial Intelligence
# Reached end of results for Artificial Intelligence.
# Processing topic: Mechanical Design
# Reached end of results for Mechanical Design.
# Processing topic: Electronics
# Reached end of results for Electronics.
# Processing topic: Theory of Computation
# Reached end of results for Theory of Computation.
# Processing topic: Digital Systems
# Reached end of results for Digital Systems.
# Processing topic: Energy
# Reached end of results for Energy.
# Processing topic: Ocean Engineering
# Reached end of results for Ocean Engineering.
# Processing topic: Signal Processing
# Reached end of results for Signal Processing.
# Processing topic: Computer Design and Engineering
# Reached end of results for Computer Design and Engineering.
# Processing topic: Robotics and Control Systems
# Reached end of results for Robotics and Control Systems.
# Processing topic: Programming Languages
# Reached end of results for Programming Languages.
# Processing topic: Solid Mechanics
# Reached end of results for Solid Mechanics.
# Processing topic: Civil Engineering
# Reached end of results for Civil Engineering.
# Processing topic: Computation
# Reached end of results for Computation.
# Processing topic: Digital Media
# Reached end of results for Digital Media.
# Processing topic: Systems Optimization
# Reached end of results for Systems Optimization.
# Processing topic: Geophysics
# Reached end of results for Geophysics.
# Processing topic: Algebra and Number Theory
# Reached end of results for Algebra and Number Theory.
# Processing topic: Atomic, Molecular, Optical Physics
# Reached end of results for Atomic, Molecular, Optical Physics.
# Processing topic: Mathematical Analysis
# Reached end of results for Mathematical Analysis.
# Processing topic: Physical Chemistry
# Reached end of results for Physical Chemistry.
# Processing topic: Data Mining
# Reached end of results for Data Mining.
# Processing topic: Hydrodynamics
# Reached end of results for Hydrodynamics.
# Processing topic: Environmental Engineering
# Reached end of results for Environmental Engineering.
# Processing topic: Information Technology
# Reached end of results for Information Technology.
# Processing topic: Systems Design
# Reached end of results for Systems Design.
# Processing topic: Topology and Geometry
# Reached end of results for Topology and Geometry.
# Processing topic: Neuroscience
# Reached end of results for Neuroscience.
# Processing topic: Nanotechnology
# Reached end of results for Nanotechnology.
# Processing topic: Geology
# Reached end of results for Geology.
# Processing topic: Propulsion Systems
# Reached end of results for Propulsion Systems.
# Processing topic: Telecommunications
# Reached end of results for Telecommunications.
# Processing topic: Materials Selection
# Reached end of results for Materials Selection.
# Processing topic: Oceanography
# Reached end of results for Oceanography.
# Processing topic: Molecular Biology
# Reached end of results for Molecular Biology.
# Processing topic: Genetics
# Reached end of results for Genetics.
# Processing topic: Transport Processes
# Reached end of results for Transport Processes.
# Processing topic: Nuclear Engineering
# Reached end of results for Nuclear Engineering.
# Processing topic: Atmospheric Science
# Reached end of results for Atmospheric Science.
# Processing topic: Nuclear Physics
# Reached end of results for Nuclear Physics.
# Processing topic: Computer Networks
# Reached end of results for Computer Networks.
# Processing topic: Dynamics and Control
# Reached end of results for Dynamics and Control.
# Processing topic: Biochemistry
# Reached end of results for Biochemistry.
# Processing topic: Biomaterials
# Reached end of results for Biomaterials.
# Processing topic: Environmental Science
# Reached end of results for Environmental Science.
# Processing topic: Cell Biology
# Reached end of results for Cell Biology.
# Processing topic: Graphics and Visualization
# Reached end of results for Graphics and Visualization.
# Processing topic: Particle Physics
# Reached end of results for Particle Physics.
# Processing topic: Computational Science and Engineering
# Reached end of results for Computational Science and Engineering.
# Processing topic: Theoretical Physics
# Reached end of results for Theoretical Physics.
# Processing topic: Computation and Systems Biology
# Reached end of results for Computation and Systems Biology.
# Processing topic: Organic Chemistry
# Reached end of results for Organic Chemistry.
# Processing topic: Neurobiology
# Reached end of results for Neurobiology.
# Processing topic: Structural Engineering
# Reached end of results for Structural Engineering.
# Processing topic: Game Design
# Reached end of results for Game Design.
# Processing topic: Computational Biology
# Reached end of results for Computational Biology.
# Processing topic: Game Theory
# Reached end of results for Game Theory.
# Processing topic: Structural Mechanics
# Reached end of results for Structural Mechanics.
# Processing topic: Anatomy and Physiology
# Reached end of results for Anatomy and Physiology.
# Processing topic: Biomedicine
# Reached end of results for Biomedicine.
# Processing topic: Planetary Science
# Reached end of results for Planetary Science.
# Processing topic: Electronic Materials
# Reached end of results for Electronic Materials.
# Processing topic: Technology
# Reached end of results for Technology.
# Processing topic: Electricity
# Reached end of results for Electricity.
# Processing topic: Nuclear
# Reached end of results for Nuclear.
# Processing topic: Sensory-Neural Systems
# Reached end of results for Sensory-Neural Systems.
# Processing topic: Econometrics
# Reached end of results for Econometrics.
# Processing topic: Human-Computer Interfaces
# Reached end of results for Human-Computer Interfaces.
# Processing topic: Microtechnology
# Reached end of results for Microtechnology.
# Processing topic: Hydrology and Water Resource Systems
# Reached end of results for Hydrology and Water Resource Systems.
# Processing topic: Cell and Tissue Engineering
# Reached end of results for Cell and Tissue Engineering.
# Processing topic: Analytical Chemistry
# Reached end of results for Analytical Chemistry.
# Processing topic: Numerical Simulation
# Reached end of results for Numerical Simulation.
# Processing topic: Biophysics
# Reached end of results for Biophysics.
# Processing topic: Geography
# Reached end of results for Geography.
# Processing topic: Aquatic Sciences and Water Quality Control
# Reached end of results for Aquatic Sciences and Water Quality Control.
# Processing topic: Cryptography
# Reached end of results for Cryptography.
# Processing topic: Aerodynamics
# Reached end of results for Aerodynamics.
# Processing topic: Condensed Matter Physics
# Reached end of results for Condensed Matter Physics.
# Processing topic: Medical Imaging
# Reached end of results for Medical Imaging.
# Processing topic: Spectroscopy
# Reached end of results for Spectroscopy.
# Processing topic: Climate
# Reached end of results for Climate.
# Processing topic: Ecology
# Reached end of results for Ecology.
# Processing topic: Astrophysics
# Reached end of results for Astrophysics.
# Processing topic: Metallurgical Engineering
# Reached end of results for Metallurgical Engineering.
# Processing topic: Hydrodynamics and Coastal Engineering
# Reached end of results for Hydrodynamics and Coastal Engineering.
# Processing topic: Fossil Fuels
# Reached end of results for Fossil Fuels.
# Processing topic: Ocean Structures
# Reached end of results for Ocean Structures.
# Processing topic: Electric Power
# Reached end of results for Electric Power.
# Processing topic: Transportation Engineering
# Reached end of results for Transportation Engineering.
# Processing topic: Functional Genomics
# Reached end of results for Functional Genomics.
# Processing topic: Biomedical Signal and Image Processing
# Reached end of results for Biomedical Signal and Image Processing.
# Processing topic: Biotechnology
# Reached end of results for Biotechnology.
# Processing topic: Synthetic Biology
# Reached end of results for Synthetic Biology.
# Processing topic: Architectural Engineering
# Reached end of results for Architectural Engineering.
# Processing topic: Microbiology
# Reached end of results for Microbiology.
# Processing topic: Polymeric Materials
# Reached end of results for Polymeric Materials.
# Processing topic: Inorganic Chemistry
# Reached end of results for Inorganic Chemistry.
# Processing topic: Graphic Design
# Reached end of results for Graphic Design.
# Processing topic: Biomechanics
# Reached end of results for Biomechanics.
# Processing topic: Astrodynamics
# Reached end of results for Astrodynamics.
# Processing topic: Pharmacology and Toxicology
# Reached end of results for Pharmacology and Toxicology.
# Processing topic: Polymers
# Reached end of results for Polymers.
# Processing topic: High Energy Physics
# Reached end of results for High Energy Physics.
# Processing topic: Nuclear Materials
# Reached end of results for Nuclear Materials.
# Processing topic: Pathology and Pathophysiology
# Reached end of results for Pathology and Pathophysiology.
# Processing topic: Ocean Exploration
# Reached end of results for Ocean Exploration.
# Processing topic: Mathematical Logic
# Reached end of results for Mathematical Logic.
# Processing topic: Hydrogen and Alternatives
# Reached end of results for Hydrogen and Alternatives.
# Processing topic: Biostatistics
# Reached end of results for Biostatistics.
# Processing topic: Geobiology
# Reached end of results for Geobiology.
# Processing topic: Virology
# Reached end of results for Virology.
# Processing topic: Structural Biology
# Reached end of results for Structural Biology.
# Processing topic: Geotechnical Engineering
# Reached end of results for Geotechnical Engineering.
# Processing topic: Molecular Engineering
# Reached end of results for Molecular Engineering.
# Processing topic: Bioastronautics
# Reached end of results for Bioastronautics.
# Processing topic: Epidemiology
# Reached end of results for Epidemiology.
# Processing topic: Radiological Engineering
# Reached end of results for Radiological Engineering.
# Processing topic: Cellular and Molecular Medicine
# Reached end of results for Cellular and Molecular Medicine.
# Processing topic: Immunology
# Reached end of results for Immunology.
# Processing topic: Health and Exercise Science
# Reached end of results for Health and Exercise Science.
# Processing topic: Composite Materials
# Reached end of results for Composite Materials.
# Processing topic: Stem Cells
# Reached end of results for Stem Cells.
# Data saved to lecture_videos_data.json
